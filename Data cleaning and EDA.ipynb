# %% [markdown]
# ## EDA and Data cleaning
# A. Loading data through pandas
#
# 1. Pandas built-in functions
#
# 2. Printing to the screen specific areas of a dataframe
#
# 3. Combining two dataframes
#
# B. General statistics of a dataframe
#
# 1. Data types
#
# 2. Missing data
#
# 3. Data statistics
#
# C. Data visualization
#
# 1. Deep diving in specific parameters
#
# 2. Visualising variable distributions
#
# D. Data cleaning
#
# 1. Missing data / Empty values
#
# 2. Duplicates
#
# E. Format/ Convert data
#
# 1. Dates
#
# 2. Negative Data
#
# 3. Missing Data
#
# F. Saving the data in pickle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('max_columns',100)
pd.set_option('max_colwidth',1000)
# %cd "churn modeling\"
# Out:
# [WinError 2] The system cannot find the file specified: 'churn modeling\\'
# C:\Users\Ali\churn modeling

# %% [markdown]
# ## Loading Data

# %%
train = pd.read_csv('ml_case_training_data.csv')
train.head(5)
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
history = pd.read_csv('ml_case_training_hist_data.csv')
history.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
churn = pd.read_csv('ml_case_training_output.csv')
churn.head()
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %%
print(train.shape)
train.info()
# Out:
# (16096, 32)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   activity_new              6551 non-null   object
#  2   campaign_disc_ele         0 non-null      float64
#  3   channel_sales             11878 non-null  object
#  4   cons_12m                  16096 non-null  int64
#  5   cons_gas_12m              16096 non-null  int64
#  6   cons_last_month           16096 non-null  int64
#  7   date_activ                16096 non-null  object
#  8   date_end                  16094 non-null  object
#  9   date_first_activ          3508 non-null   object
#  10  date_modif_prod           15939 non-null  object
#  11  date_renewal              16056 non-null  object
#  12  forecast_base_bill_ele    3508 non-null   float64
# ...

# %% [markdown]
# ## Combining 2 DataFrames

# %%
train = pd.merge(train , churn , on = 'id')
train.tail(5)
# Out:
#                                      id activity_new  campaign_disc_ele  \
# 16091  18463073fb097fc0ac5d3e040f356987          NaN                NaN
# 16092  d0a6f71671571ed83b2645d23af6de00          NaN                NaN
# 16093  10e6828ddd62cbcf687cb74928c4c2d2          NaN                NaN
# 16094  1cf20fd6206d7678d5bcafd28c53b4db          NaN                NaN
# 16095  563dde550fd624d7352f3de77c0cdfcd          NaN                NaN
#
#                           channel_sales  cons_12m  cons_gas_12m  \
# 16091  foosdfpfkusacimwkcsosbicdxkicaua     32270         47940
# 16092  foosdfpfkusacimwkcsosbicdxkicaua      7223             0
# 16093  foosdfpfkusacimwkcsosbicdxkicaua      1844             0
# 16094  foosdfpfkusacimwkcsosbicdxkicaua       131             0
# 16095                               NaN      8730             0
#
#        cons_last_month  date_activ    date_end date_first_activ  \
# 16091                0  2012-05-24  2016-05-08              NaN
# ...

# %% [markdown]
# ## B. General statistics of a dataframe
# #### Data Types
# Often, it is useful to understand what data we are dealing with, as the data types might end up causing errors into our analysis at a later stage.
#
# Below, we can quickly see the dates in our dataset are not datetime types yet, which means we might need to convert them.
# #### Missing Data
# We are also concerned we have a lot of missing data so we can check how much of our data is missing.

# %%
pd.DataFrame({'DTYPES' : train.dtypes , 'Nulls': train.isnull().sum() , "Null_percentage":train.isnull().sum()/len(train.index) * 100})
# Out:
#                            DTYPES  Nulls  Null_percentage
# id                         object      0         0.000000
# activity_new               object   9545        59.300447
# campaign_disc_ele         float64  16096       100.000000
# channel_sales              object   4218        26.205268
# cons_12m                    int64      0         0.000000
# cons_gas_12m                int64      0         0.000000
# cons_last_month             int64      0         0.000000
# date_activ                 object      0         0.000000
# date_end                   object      2         0.012425
# date_first_activ           object  12588        78.205765
# date_modif_prod            object    157         0.975398
# date_renewal               object     40         0.248509
# forecast_base_bill_ele    float64  12588        78.205765
# forecast_base_bill_year   float64  12588        78.205765
# forecast_bill_12m         float64  12588        78.205765
# ...

# %%
pd.DataFrame({'DTYPES' : history.dtypes , 'Nulls': history.isnull().sum() , "Null_percentage":history.isnull().sum()/len(history.index) * 100})
# Out:
#                DTYPES  Nulls  Null_percentage
# id             object      0         0.000000
# price_date     object      0         0.000000
# price_p1_var  float64   1359         0.704138
# price_p2_var  float64   1359         0.704138
# price_p3_var  float64   1359         0.704138
# price_p1_fix  float64   1359         0.704138
# price_p2_fix  float64   1359         0.704138
# price_p3_fix  float64   1359         0.704138

# %%
train["campaign_disc_ele"].isnull().values.all()
# Out:
# True

# %% [markdown]
# ### Data general statistics

# %%
train.describe()
# Out:
#        campaign_disc_ele      cons_12m  cons_gas_12m  cons_last_month  \
# count                0.0  1.609600e+04  1.609600e+04     1.609600e+04
# mean                 NaN  1.948044e+05  3.191164e+04     1.946154e+04
# std                  NaN  6.795151e+05  1.775885e+05     8.235676e+04
# min                  NaN -1.252760e+05 -3.037000e+03    -9.138600e+04
# 25%                  NaN  5.906250e+03  0.000000e+00     0.000000e+00
# 50%                  NaN  1.533250e+04  0.000000e+00     9.010000e+02
# 75%                  NaN  5.022150e+04  0.000000e+00     4.127000e+03
# max                  NaN  1.609711e+07  4.188440e+06     4.538720e+06
#
#        forecast_base_bill_ele  forecast_base_bill_year  forecast_bill_12m  \
# count             3508.000000              3508.000000        3508.000000
# mean               335.843857               335.843857        3837.441866
# std                649.406000               649.406000        5425.744327
# ...

# %%
history.describe()
# Out:
#         price_p1_var   price_p2_var   price_p3_var   price_p1_fix  \
# count  191643.000000  191643.000000  191643.000000  191643.000000
# mean        0.140991       0.054412       0.030712      43.325546
# std         0.025117       0.050033       0.036335       5.437952
# min         0.000000       0.000000       0.000000      -0.177779
# 25%         0.125976       0.000000       0.000000      40.728885
# 50%         0.146033       0.085483       0.000000      44.266930
# 75%         0.151635       0.101780       0.072558      44.444710
# max         0.280700       0.229788       0.114102      59.444710
#
#         price_p2_fix   price_p3_fix
# count  191643.000000  191643.000000
# mean       10.698201       6.455436
# std        12.856046       7.782279
# min        -0.097752      -0.065172
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%        24.339581      16.226389
# max        36.490692      17.458221

# %% [markdown]
# ## C. Data visualization
# Deep diving a little bit on the main parameters

# %% [markdown]
# ## Churn
# Let's see the churning rate

# %%
churn = train[['id' , 'churn']]
churn.columns = ["Companies", "churn"]
churn
# Out:
#                               Companies  churn
# 0      48ada52261e7cf58715202705a0451c9      0
# 1      24011ae4ebbe3035111d65fa7c15bc57      1
# 2      d29c2c54acc38ff3c0614d0a653813dd      0
# 3      764c75f661154dac3a6c254cd082ea7d      0
# 4      bba03439a292a1e166f80264c16191cb      0
# ...                                 ...    ...
# 16091  18463073fb097fc0ac5d3e040f356987      0
# 16092  d0a6f71671571ed83b2645d23af6de00      1
# 16093  10e6828ddd62cbcf687cb74928c4c2d2      1
# 16094  1cf20fd6206d7678d5bcafd28c53b4db      0
# 16095  563dde550fd624d7352f3de77c0cdfcd      0
#
# [16096 rows x 2 columns]

# %%
churn_total = churn.groupby(churn["churn"]).count()
churn_percentage = churn_total/churn_total.sum()*100
churn_percentage
# Out:
#        Companies
# churn
# 0      90.090706
# 1       9.909294

# %%
churn_percentage.plot(kind  = 'bar' , stacked = True )
# Out:
# <AxesSubplot:xlabel='churn'>

# %%
churn_percentage.transpose().plot(kind = 'bar' , stacked = True)
# Out:
# <AxesSubplot:>

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
     """
     Plot stacked bars with annotations
     """
     ax = dataframe.plot(kind="bar",
     stacked=True,
     figsize=size_,
     rot=rot_,
     title=title_)
     # Annotate bars
     annotate_stacked_bars(ax, textsize=14)
     # Rename legend
     plt.legend(["Retention", "Churn"], loc=legend_)
     # Labels
     plt.ylabel("Company base (%)")
     plt.show()
def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
     """
     Add value annotations to the bars
     """
     # Iterate over the plotted rectanges/bars
     for p in ax.patches:
     # Calculate annotation
        value = str(round(p.get_height(),1))
     # If value is 0 do not annotate
        if value == '0.0':
             continue
        ax.annotate(value,
        ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
        color=colour,
        size=textsize,
     )

# %%
churn_percentage.transpose()
# Out:
# churn              0         1
# Companies  90.090706  9.909294

# %%
plot_stacked_bars(churn_percentage.transpose() , title_="Churn percentage" , size_=(5,5))

# %% [markdown]
# ### SME activity
# Let's show the activity distribution of the companies as well as the sales channel.
#
# This might be an important predictive feature for energy consumption

# %%
train.head(2)
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# 1         54946                0  2013-06-15  2016-06-15              NaN
#
#   date_modif_prod date_renewal  forecast_base_bill_ele  \
# 0      2012-11-07   2015-11-09                     NaN
# 1             NaN   2015-06-23                     NaN
#
#    forecast_base_bill_year  forecast_bill_12m  forecast_cons  \
# 0                      NaN                NaN            NaN
# ...

# %%
activity = train.groupby([train["activity_new"],
 train["churn"]])["id"].count().unstack(level = 1).sort_values(by=[0], ascending=False)

activity
# Out:
# churn                                  0     1
# activity_new
# apdekpcbwosbxepsfxclislboipuxpop  1484.0  93.0
# kkklcdamwfafdcfwofuscwfwadblfmce   384.0  38.0
# kwuslieomapmswolewpobpplkaooaaew   200.0  30.0
# fmwdwsxillemwbbwelxsampiuwwpcdcb   187.0  32.0
# ckfxocssowaeipxueikxcmaxdmcduxsa   176.0  13.0
# ...                                  ...   ...
# opoiuuwdmxdssidluooopfswlkkkcsxf     NaN   1.0
# pfcocskbxlmofswiflsbcefcpufbopuo     NaN   2.0
# wceaopxmdpccxfmcdpopulcaubcxibuw     NaN   1.0
# wkwdccuiboaeaalcaawlwmldiwmpewma     NaN   1.0
# xwkaesbkfsacseixxksofpddwfkbobki     NaN   1.0
#
# [419 rows x 2 columns]

# %%
# Another method 
bb = activity.fillna(0)
bb['Total_cpmpanies'] = bb[(0)] + bb[(1)]
bb['percentage_churn'] = bb[(1)] / (bb['Total_cpmpanies']) * 100
bb.sort_values(by = 'Total_cpmpanies' , ascending = False)
# Out:
# churn                                  0     1  Total_cpmpanies  \
# activity_new
# apdekpcbwosbxepsfxclislboipuxpop  1484.0  93.0           1577.0
# kkklcdamwfafdcfwofuscwfwadblfmce   384.0  38.0            422.0
# kwuslieomapmswolewpobpplkaooaaew   200.0  30.0            230.0
# fmwdwsxillemwbbwelxsampiuwwpcdcb   187.0  32.0            219.0
# ckfxocssowaeipxueikxcmaxdmcduxsa   176.0  13.0            189.0
# ...                                  ...   ...              ...
# eckbfdkkkfoxpeffpacbikwpeicksulu     1.0   0.0              1.0
# eamiapdokbfumefocubefudcowecllla     1.0   0.0              1.0
# dxmfpsflslufmxlmwdmbkikffowmfmum     1.0   0.0              1.0
# dwdflbsopucwoxdmccmulwiiefiiabel     1.0   0.0              1.0
# xwkaesbkfsacseixxksofpddwfkbobki     0.0   1.0              1.0
#
# churn                             percentage_churn
# activity_new
# apdekpcbwosbxepsfxclislboipuxpop          5.897273
# kkklcdamwfafdcfwofuscwfwadblfmce          9.004739
# ...

# %%
activity.plot(kind="bar",
 figsize=(18, 10),
 width=2,
 stacked=True,
 title="SME Activity")
# Labels
plt.ylabel("Number of companies")
plt.xlabel("Activity")
# Rename legend
plt.legend(["Retention", "Churn"], loc="upper right")
# Remove the label for the xticks as the categories are encoded and we can't draw any meaning from them yet
plt.xticks([])
plt.show()

# %% [markdown]
# We see churn is not specifically related to any SME cateogry in particular.
# ## Note:
# Not showing the labels in the x-axis to facilitate visualization
#
# If we take a look at the values percentage-wise below :

# %%
# Second method part1
activity_total = activity.fillna(0)[0]+activity.fillna(0)[1]
activity_total
# Out:
# activity_new
# apdekpcbwosbxepsfxclislboipuxpop    1577.0
# kkklcdamwfafdcfwofuscwfwadblfmce     422.0
# kwuslieomapmswolewpobpplkaooaaew     230.0
# fmwdwsxillemwbbwelxsampiuwwpcdcb     219.0
# ckfxocssowaeipxueikxcmaxdmcduxsa     189.0
#                                      ...
# opoiuuwdmxdssidluooopfswlkkkcsxf       1.0
# pfcocskbxlmofswiflsbcefcpufbopuo       2.0
# wceaopxmdpccxfmcdpopulcaubcxibuw       1.0
# wkwdccuiboaeaalcaawlwmldiwmpewma       1.0
# xwkaesbkfsacseixxksofpddwfkbobki       1.0
# Length: 419, dtype: float64

# %%
# Second method part2
activity_percentage = activity.fillna(0)[1]/(activity_total)*100
pd.DataFrame({"Percentage churn": activity_percentage,
 "Total companies": activity_total }).sort_values(by="Total companies",
 ascending=False).head(10)
# Out:
#                                   Percentage churn  Total companies
# activity_new
# apdekpcbwosbxepsfxclislboipuxpop          5.897273           1577.0
# kkklcdamwfafdcfwofuscwfwadblfmce          9.004739            422.0
# kwuslieomapmswolewpobpplkaooaaew         13.043478            230.0
# fmwdwsxillemwbbwelxsampiuwwpcdcb         14.611872            219.0
# ckfxocssowaeipxueikxcmaxdmcduxsa          6.878307            189.0
# cwofmuicebbcmiaaxufmfimpowpacobu          9.836066            122.0
# cluecxlameloamldmasudocsbmaoamdw         11.764706            119.0
# wxemiwkumpibllwklfbcooafckufkdlm         14.285714            119.0
# sfisfxfcocfpcmckuekokxuseixdaoeu          6.024096             83.0
# sffadmsbuamddwapeumdfibkmpkdicmc          8.000000             75.0

# %% [markdown]
# ## How SME activity will help in predictive model ?
# Above ativity_new does not impact most on our model bcz the churn customers are not belong from a certain category .
#
# Our predictive model is likely to struggle accurately predicting the the SME activity due to the large number of categories and low number of companies belonging to each category.

# %% [markdown]
# ## Sales channel

# %%
channel = train[['id' , 'churn' , 'channel_sales']]
channel = channel.groupby(by = ['channel_sales' , 'churn'])['id'].count().unstack(level = 1).fillna(0)
channel
# Out:
# churn                                  0      1
# channel_sales
# epumfxlbckeskwekxbiuasklxalciiuu     4.0    0.0
# ewpakwlliwisiwduibdlfmalxowmwpci   884.0   82.0
# fixdbufsefwooaasfcxdxadsiekoceaa     2.0    0.0
# foosdfpfkusacimwkcsosbicdxkicaua  6455.0  922.0
# lmkebamcaaclubfxadlmueccxoimlema  1957.0  116.0
# sddiedcslfslkckwlfkdpoeeailfpeds    12.0    0.0
# usilxuppasemubllopkaafesmlibmsdf  1294.0  150.0

# %%
# Get Floating division of dataframe and other, element-wise (binary operator `truediv`).
# df.add() , df.mul() , df.sub() , df.flrdiv()
channel_churn = (channel.div(channel.sum(axis=1), axis=0)*100).sort_values(by=[1])
channel_churn
# Out:
# churn                                      0          1
# channel_sales
# epumfxlbckeskwekxbiuasklxalciiuu  100.000000   0.000000
# fixdbufsefwooaasfcxdxadsiekoceaa  100.000000   0.000000
# sddiedcslfslkckwlfkdpoeeailfpeds  100.000000   0.000000
# lmkebamcaaclubfxadlmueccxoimlema   94.404245   5.595755
# ewpakwlliwisiwduibdlfmalxowmwpci   91.511387   8.488613
# usilxuppasemubllopkaafesmlibmsdf   89.612188  10.387812
# foosdfpfkusacimwkcsosbicdxkicaua   87.501694  12.498306

# %%
plot_stacked_bars(channel_churn , rot_=45 , title_=" channel_churn")

# %% [markdown]
# Nothing out of the normal form this graph above.
# If we look at it percentage-wise below :

# %%
total_sum = channel.sum(axis = 1)
churn_precent = (channel[1]/total_sum) * 100
pd.DataFrame({'Total_companies' : total_sum , 'Churn Prcentage': churn_precent})
# Out:
#                                   Total_companies  Churn Prcentage
# channel_sales
# epumfxlbckeskwekxbiuasklxalciiuu              4.0         0.000000
# ewpakwlliwisiwduibdlfmalxowmwpci            966.0         8.488613
# fixdbufsefwooaasfcxdxadsiekoceaa              2.0         0.000000
# foosdfpfkusacimwkcsosbicdxkicaua           7377.0        12.498306
# lmkebamcaaclubfxadlmueccxoimlema           2073.0         5.595755
# sddiedcslfslkckwlfkdpoeeailfpeds             12.0         0.000000
# usilxuppasemubllopkaafesmlibmsdf           1444.0        10.387812

# %% [markdown]
# ## Consumption
# Let's see the distribution of the consumption over the last year and last month

# %%
consumption = train[["id","cons_12m", "cons_gas_12m","cons_last_month", "imp_cons", "has_gas", "churn"]]
consumption.head(3)
# Out:
#                                  id  cons_12m  cons_gas_12m  cons_last_month  \
# 0  48ada52261e7cf58715202705a0451c9    309275             0            10025
# 1  24011ae4ebbe3035111d65fa7c15bc57         0         54946                0
# 2  d29c2c54acc38ff3c0614d0a653813dd      4660             0                0
#
#    imp_cons has_gas  churn
# 0     831.8       f      0
# 1       0.0       t      1
# 2       0.0       f      0

# %%
# The most straight forward way is to visualize through histograms and with stacked bars of churn
df= train.copy(deep = True)
column = 'cons_12m'
#def plot_distribution( df , column , ax , bins_ = 50)
temp = pd.DataFrame({"Retension ": df[df['churn'] == 0][column] , 
                         "CHurn ": df[df['churn'] == 1 ][column]})   
temp
# Out:
#        Retension   CHurn
# 0        309275.0     NaN
# 1             NaN     0.0
# 2          4660.0     NaN
# 3           544.0     NaN
# 4          1584.0     NaN
# ...           ...     ...
# 16091     32270.0     NaN
# 16092         NaN  7223.0
# 16093         NaN  1844.0
# 16094       131.0     NaN
# 16095      8730.0     NaN
#
# [16096 rows x 2 columns]

# %%
temp.plot(kind = 'hist' , bins = 50 , stacked = True ,)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def plot_distribution( df , column , ax , bins_ = 50):
    temp = pd.DataFrame({"Retension ": df[df['churn'] == 0][column] , 
                             "CHurn ": df[df['churn'] == 1 ][column]})    
     # Plot the histogram
    temp[["Retension ","CHurn "]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
     # X-axis label
    ax.set_xlabel(column)
     # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
 fig, axs = plt.subplots(nrows=4, figsize=(18,25))
# Plot histogram
plot_distribution(consumption, "cons_12m", axs[0])
# Note that the gas consumption must have gas contract
plot_distribution(consumption[consumption["has_gas"] == "t"], "cons_gas_12m", axs[1])
plot_distribution(consumption, "cons_last_month", axs[2])
plot_distribution(consumption, "imp_cons", axs[3])

# %% [markdown]
# We can clearly see in here that the consumption data is highly skewed to the right, presenting a very long right-tail towards the higher values of the distribution.
#
# The values on the higher end and lower ends of the distribution are likely to be outliers. We can use a standard plot to visualise the outliers in more detail.
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
#
# It can tell us about our outliers and what their values are.

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
fig, axs = plt.subplots(nrows=4, figsize=(18,25))
# Plot histogram
sns.boxplot(consumption["cons_12m"], ax=axs[0])
sns.boxplot(consumption[consumption["has_gas"] == "t"]["cons_gas_12m"], ax=axs[1])
sns.boxplot(consumption["cons_last_month"], ax=axs[2])
sns.boxplot(consumption["imp_cons"], ax=axs[3])
# Remove scientific notation
for ax in axs:
    ax.ticklabel_format(style='plain', axis='x')
# Set x-axis limit
axs[0].set_xlim(-200000, 2000000)
axs[1].set_xlim(-200000, 2000000) # To get a coloser look
axs[2].set_xlim(-20000, 100000)
plt.show()

# %% [markdown]
# It is very clear now that we have a highly skewed distribution, and several outliers.
#
# We will deal with the skewness and outliers in the " Data cleaning " part .

# %% [markdown]
# ### Dates

# %%
dates = train[["id","date_activ","date_end", "date_modif_prod","date_renewal","churn"]].copy()

# %%
# Transform date columns to datetime type
dates["date_activ"] = pd.to_datetime(dates["date_activ"], format='%Y-%m-%d')
dates["date_end"] = pd.to_datetime(dates["date_end"], format='%Y-%m-%d')
dates["date_modif_prod"] = pd.to_datetime(dates["date_modif_prod"], format='%Y-%m-%d')
dates["date_renewal"] = pd.to_datetime(dates["date_renewal"], format='%Y-%m-%d')

# %%
temp = dates[['date_activ',
     "churn",
     "id"]].set_index('date_activ').groupby([pd.Grouper(freq='M'), "churn"]).count().unstack(level=1)
temp
#dates[['date_activ',
 #    "churn",
  #   "id"]].set_index('date_activ')
# Out:
#               id
# churn          0    1
# date_activ
# 2000-07-31   1.0  NaN
# 2001-02-28   1.0  NaN
# 2003-05-31   1.0  NaN
# 2003-06-30   2.0  1.0
# 2003-07-31   8.0  NaN
# ...          ...  ...
# 2013-07-31  18.0  2.0
# 2013-08-31   5.0  2.0
# 2013-10-31   2.0  NaN
# 2013-11-30   1.0  1.0
# 2014-09-30   1.0  NaN
#
# [125 rows x 2 columns]

# %%
#ax.set_xticklabels(map(lambda x: line_format(x), temp.index))
l1 = list(map(lambda x : x+2 , [1,2,3,4])) # computes a function on iterable
print(l1)
label = temp.index[0]
print(label)
mon = label.month_name()
print(mon)
mon  = mon + f'11'
print(mon)
mon = label.month_name()
mon = mon + f'\n11'
print(mon)
mon = label.month_name()
mon = mon + f'\n{label.year}'
print(mon)
# Out:
# [3, 4, 5, 6]
# 2000-07-31 00:00:00
# July
# July11
# July
# 11
# July
# 2000

# %%
labels = temp.index[0:4]
print(labels) # Timestamps labels are not iterable use simple print
mons = labels.month_name().tolist()
print(mons)
new_list = []
for mo in mons:
    if mo == 'February':
        mo += f'\n11'
        new_list.append(mo)
    new_list.append(mo)
print(new_list)
print(new_list[2])
# Out:
# DatetimeIndex(['2000-07-31', '2001-02-28', '2003-05-31', '2003-06-30'], dtype='datetime64[ns]', name='date_activ', freq=None)
# ['July', 'February', 'May', 'June']
# ['July', 'February\n11', 'February\n11', 'May', 'June']
# February
# 11

# %%
ax=temp.plot(kind="bar", stacked=True, figsize=(40,10), rot=0)
ax.set_xticklabels(list(map(lambda x: line_format(x), temp.index)))
plt.show()
print(map(lambda x : line_format(x), temp.index))
print(temp.index)
# Out:
# ...
# DatetimeIndex(['2000-07-31', '2001-02-28', '2003-05-31', '2003-06-30',
#                '2003-07-31', '2003-08-31', '2003-09-30', '2003-10-31',
#                '2003-11-30', '2003-12-31',
#                ...
#                '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31',
#                '2013-06-30', '2013-07-31', '2013-08-31', '2013-10-31',
#                '2013-11-30', '2014-09-30'],
#               dtype='datetime64[ns]', name='date_activ', length=125, freq=None)

# %%
def plot_dates(dataframe, column, fontsize_=12):
     """
     Plot monthly churn and retention distribution
     """
     # Group by month
     temp = dataframe[[column,
     "churn",
     "id"]].set_index(column).groupby([pd.Grouper(freq='M'), "churn"]).count().unstack(level=1)
     # Plot
     ax=temp.plot(kind="bar", stacked=True, figsize=(18,10), rot=0)
     # Change x-axis labels to months
     ax.set_xticklabels(map(lambda x: line_format(x), temp.index))
     # Change xlabel size
     plt.xticks(fontsize=fontsize_)
     # Rename y-axis
     plt.ylabel("Number of companies")
     # Rename legend
     plt.legend(["Retention", "Churn"], loc="upper right")
     plt.show()

def line_format(label):
     """
     Convert time label to the format of pandas line plot
     """
     month = label.month_name()[:1]
     if label.month_name() == "January":
         month += f'\n{label.year}'
     return month

# %%
plot_dates(dates, "date_activ", fontsize_=8)

# %%
plot_dates(dates, "date_end")

# %%
plot_dates(dates , 'date_modif_prod' , fontsize_=8)

# %%
plot_dates(dates , 'date_renewal')

# %% [markdown]
# We can visualize the distribution of churned companies according to the date. However, this does not provide us with any useful
# insight. We will create a new features using the raw dates provided in the feature engineering part .

# %% [markdown]
# # Forecast

# %%
forecast = train[["id","forecast_base_bill_ele","forecast_base_bill_year",
 "forecast_bill_12m","forecast_cons","forecast_cons_12m",
 "forecast_cons_year","forecast_discount_energy","forecast_meter_rent_12m",
 "forecast_price_energy_p1","forecast_price_energy_p2",
 "forecast_price_pow_p1","churn"]]

# %%
 fig, axs = plt.subplots(nrows=11, figsize=(18,50))
# Plot histogram
plot_distribution(train, "forecast_base_bill_ele", axs[0])
plot_distribution(train, "forecast_base_bill_year", axs[1])
plot_distribution(train, "forecast_bill_12m", axs[2])
plot_distribution(train, "forecast_cons", axs[3])
plot_distribution(train, "forecast_cons_12m", axs[4])
plot_distribution(train, "forecast_cons_year", axs[5])
plot_distribution(train, "forecast_discount_energy", axs[6])
plot_distribution(train, "forecast_meter_rent_12m", axs[7])
plot_distribution(train, "forecast_price_energy_p1", axs[8])
plot_distribution(train, "forecast_price_energy_p2", axs[9])
plot_distribution(train, "forecast_price_pow_p1", axs[10])

# %% [markdown]
# Similarly to the consumption plots, we can observe that a lot of the variables are highly skewed to the right, creating a very long tail on the higher values.
#
# We will make some transformations to correct for this skewness .

# %% [markdown]
# ## Contract type(electricity , gas)

# %%
train['has_gas'].replace(to_replace = ['t','f'] , value = ['T' , 'F'] , inplace = True)
contract = train[['has_gas' , 'id' , 'churn']]
contract = contract.groupby(['has_gas' , 'churn'])['id'].count().unstack(level = 1)
contract
# Out:
# churn        0     1
# has_gas
# F        11771  1361
# T         2730   234

# %%
print(contract.sum(axis = 1))
contract = contract.div(contract.sum(axis = 1) , axis = 0)*100
contract
# Out:
# has_gas
# F    13132
# T     2964
# dtype: int64
# churn            0          1
# has_gas
# F        89.636004  10.363996
# T        92.105263   7.894737

# %%
plot_stacked_bars(contract , title_="Contract_type" )

# %% [markdown]
# ## Margins

# %%
margin = train[["id","margin_gross_pow_ele","margin_net_pow_ele","net_margin"]]

# %%
fig, axs = plt.subplots(nrows=3, figsize=(18,20))
# Plot histogram
sns.boxplot(margin["margin_gross_pow_ele"], ax=axs[0])
sns.boxplot(margin["margin_net_pow_ele"],ax=axs[1])
sns.boxplot(margin["net_margin"], ax=axs[2])
# Remove scientific notation
axs[0].ticklabel_format(style='plain', axis='x')
axs[1].ticklabel_format(style='plain', axis='x')
axs[2].ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# We can observe a few outliers in here as well.

# %% [markdown]
# ## Subscribed power

# %%
power = train[['id' , 'pow_max' , 'churn']]

# %%
fig , axs = plt.subplots(nrows = 1  , figsize = (18,8))
plot_distribution(power , 'pow_max' , ax=axs)

# %% [markdown]
# ## Others

# %%
others = train[["id","nb_prod_act","num_years_antig", "origin_up", "churn"]]

# %%
prod_act = others.groupby(['nb_prod_act','churn'])['id'].count().unstack(level = 1).fillna(0)
prod_act = prod_act.div(prod_act.sum(axis = 1) , axis = 0)*100
prod_act
# Out:
# churn                 0          1
# nb_prod_act
# 1             89.697452  10.302548
# 2             91.617430   8.382570
# 3             90.017825   9.982175
# 4             91.176471   8.823529
# 5             91.891892   8.108108
# 6            100.000000   0.000000
# 8            100.000000   0.000000
# 9            100.000000   0.000000
# 10           100.000000   0.000000
# 31           100.000000   0.000000
# 32           100.000000   0.000000

# %%
no_of_year = others.groupby(['num_years_antig','churn'])['id'].count().unstack(level = 1).fillna(0)
no_of_year = no_of_year.div(no_of_year.sum(axis = 1) , axis = 0)*100
no_of_year
# Out:
# churn                     0          1
# num_years_antig
# 1                100.000000   0.000000
# 2                 72.727273  27.272727
# 3                 86.543344  13.456656
# 4                 87.716463  12.283537
# 5                 91.302605   8.697395
# 6                 92.718639   7.281361
# 7                 91.975309   8.024691
# 8                 94.059406   5.940594
# 9                 99.056604   0.943396
# 10                93.805310   6.194690
# 11                92.796610   7.203390
# 12                88.976378  11.023622
# 13                92.307692   7.692308
# 15               100.000000   0.000000
# 16               100.000000   0.000000

# %%
origin = others.groupby(['origin_up','churn'])['id'].count().unstack(level = 1).fillna(0)
origin = origin.div(origin.sum(axis = 1) , axis = 0)*100
origin
# Out:
# churn                                      0          1
# origin_up
# ewxeelcelemmiwuafmddpobolfuxioce  100.000000   0.000000
# kamkkxfxxuwbdslkwifmmcsiusiuosws   94.133274   5.866726
# ldkssxwpmemidmecebumciepifcamkci   91.402838   8.597162
# lxidpiddsbxsbosboudacockeimpuepw   87.092652  12.907348
# usapbepcfoloekilkwsdiboslwaxobdp  100.000000   0.000000

# %%
prod_act.plot(kind = 'bar' , stacked = True)
# Out:
# <AxesSubplot:xlabel='nb_prod_act'>

# %%
plot_stacked_bars(prod_act , "Product activation")

# %%
plot_stacked_bars(no_of_year , "No.of years anigue")

# %%
plot_stacked_bars(origin , title_="Origin of customers" , rot_=45)

# %% [markdown]
# ## D. Data Cleaning
# 1. Missing data

# %%
missing = (train.isnull().sum()/len(train.index))*100
missing.plot(kind = 'bar' , figsize = (18,8))
plt.ylabel('Total_percentage(%) of missing values')
plt.xlabel("Columns")
plt.show()

# %%
train[train['date_end'].isnull()]
# Out:
#                                      id                      activity_new  \
# 4452   f7aed20b79f48e9e87687dc74fc6a353  ilkfsaapsxpkcpswbllddfmpamwelpxi
# 12880  ec6c8b46866d76e99623ddcf9d334835  mloxfblllfoxllsffauklsewwfcfdlls
#
#                           channel_sales  cons_12m  cons_gas_12m  \
# 4452   foosdfpfkusacimwkcsosbicdxkicaua    107905             0
# 12880                               NaN     18954             0
#
#        cons_last_month  date_activ date_end date_modif_prod date_renewal  \
# 4452                 0  2013-06-19      NaN             NaN          NaN
# 12880             1596  2010-09-06      NaN      2015-05-24          NaN
#
#        forecast_cons_12m  forecast_cons_year  forecast_discount_energy  \
# 4452            10507.01                   0                       0.0
# 12880            1978.40                1596                      22.0
#
#        forecast_meter_rent_12m  forecast_price_energy_p1  \
# ...

# %% [markdown]
# ## We will remove columns that have more then 60% of nulls

# %%
train.drop(columns=["campaign_disc_ele", "date_first_activ",
 "forecast_base_bill_ele","forecast_base_bill_year",
"forecast_bill_12m", "forecast_cons"], inplace=True)
train.head(3)
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
#
#                       channel_sales  cons_12m  cons_gas_12m  cons_last_month  \
# 0  lmkebamcaaclubfxadlmueccxoimlema    309275             0            10025
# 1  foosdfpfkusacimwkcsosbicdxkicaua         0         54946                0
# 2                               NaN      4660             0                0
#
#    date_activ    date_end date_modif_prod date_renewal  forecast_cons_12m  \
# 0  2012-11-07  2016-11-06      2012-11-07   2015-11-09           26520.30
# 1  2013-06-15  2016-06-15             NaN   2015-06-23               0.00
# 2  2009-08-21  2016-08-30      2009-08-21   2015-08-31             189.95
#
# ...

# %% [markdown]
# ## 2. Duplicates
#
# We want to make sure all the data we have is unique and we don't have any duplicated rows. For that, we're going to use the .duplicated()
# function in pandas.
#
# This will tell us if there are any duplicated rows.

# %%
print(train.duplicated().sum())
train[train.duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [id, activity_new, channel_sales, cons_12m, cons_gas_12m, cons_last_month, date_activ, date_end, date_modif_prod, date_renewal, forecast_cons_12m, forecast_cons_year, forecast_discount_energy, forecast_meter_rent_12m, forecast_price_energy_p1, forecast_price_energy_p2, forecast_price_pow_p1, has_gas, imp_cons, margin_gross_pow_ele, margin_net_pow_ele, nb_prod_act, net_margin, num_years_antig, origin_up, pow_max, churn]
# Index: []

# %% [markdown]
# ## E . Format/convert missing data
# #### Missing dates
# There could be several ways in which we could deal with the missing dates.
#
# The simplest way, we will replace the missing values with the median (the most frequent date) using the command .value_counts()

# %%
date_mod = train['date_modif_prod'].value_counts().index[0]
date_renew = train['date_renewal'].value_counts().index[0]
date_end  = train['date_end'].value_counts().index[0]
print(date_mod , date_renew , date_end )
# Out:
# 2015-11-01 2015-06-23 2016-02-01

# %%
train.loc[train['date_modif_prod'].isnull() , 'date_modif_prod'] = date_mod
train.loc[train['date_renewal'].isnull() , 'date_renewal'] = date_renew
train.loc[train['date_end'].isnull() , 'date_end'] = date_end

# %%
history.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
missing_precentge = (history.isnull().sum()/len(history.index))*100
missing_precentge
# Out:
# id              0.000000
# price_date      0.000000
# price_p1_var    0.704138
# price_p2_var    0.704138
# price_p3_var    0.704138
# price_p1_fix    0.704138
# price_p2_fix    0.704138
# price_p3_fix    0.704138
# dtype: float64

# %%
missing_precentge.plot(kind = 'bar' , stacked = True , figsize = (18,8))
plt.xlabel('Variables')
plt.ylabel("percentage of missing values (%)")
plt.show()

# %% [markdown]
# # there are not much missing data in history csv , so we'll simply be imputing with mean

# %%
history.loc[history["price_p1_var"].isnull(),"price_p1_var"] = history["price_p1_var"].median()
history.loc[history["price_p2_var"].isnull(),"price_p2_var"] = history["price_p2_var"].median()
history.loc[history["price_p3_var"].isnull(),"price_p3_var"] = history["price_p3_var"].median()
history.loc[history["price_p1_fix"].isnull(),"price_p1_fix"] = history["price_p1_fix"].median()
history.loc[history["price_p2_fix"].isnull(),"price_p2_fix"] = history["price_p2_fix"].median()
history.loc[history["price_p3_fix"].isnull(),"price_p3_fix"] = history["price_p3_fix"].median()

# %% [markdown]
# ### Transforming the dates to be used in predictive modeling

# %%
history["price_date"] = pd.to_datetime(history["price_date"], format='%Y-%m-%d')
train["date_activ"] = pd.to_datetime(train["date_activ"], format='%Y-%m-%d')
train["date_end"] = pd.to_datetime(train["date_end"], format='%Y-%m-%d')
train["date_modif_prod"] = pd.to_datetime(train["date_modif_prod"], format='%Y-%m-%d')
train["date_renewal"] = pd.to_datetime(train["date_renewal"], format='%Y-%m-%d')

# %%
pd.DataFrame({'Columns ' : train.dtypes , "Nulls" : train.isnull().sum()})
# Out:
#                                 Columns   Nulls
# id                                object      0
# activity_new                      object   9545
# channel_sales                     object   4218
# cons_12m                           int64      0
# cons_gas_12m                       int64      0
# cons_last_month                    int64      0
# date_activ                datetime64[ns]      0
# date_end                  datetime64[ns]      0
# date_modif_prod           datetime64[ns]      0
# date_renewal              datetime64[ns]      0
# forecast_cons_12m                float64      0
# forecast_cons_year                 int64      0
# forecast_discount_energy         float64    126
# forecast_meter_rent_12m          float64      0
# forecast_price_energy_p1         float64    126
# forecast_price_energy_p2         float64    126
# forecast_price_pow_p1            float64    126
# has_gas                           object      0
# imp_cons                         float64      0
# ...

# %%
train['forecast_price_energy_p1'].dropna()
# Out:
# 0        0.095919
# 1        0.114481
# 2        0.145711
# 3        0.165794
# 4        0.146694
#            ...
# 16091    0.138305
# 16092    0.100167
# 16093    0.116900
# 16094    0.145711
# 16095    0.167086
# Name: forecast_price_energy_p1, Length: 15970, dtype: float64

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
fig, axs = plt.subplots(nrows=6, figsize=(18,50))
# Plot boxplots
sns.boxplot((train["cons_12m"].dropna()), ax=axs[0])
sns.boxplot((train[train["has_gas"]==1]["cons_gas_12m"].dropna()), ax=axs[1])
sns.boxplot((train["cons_last_month"].dropna()), ax=axs[2])
sns.boxplot((train["forecast_cons_12m"].dropna()), ax=axs[3])
#sns.boxplot((train["forecast_cons_year"].dropna()), ax=axs[4])
sns.boxplot((train["forecast_meter_rent_12m"].dropna()), ax=axs[4])
sns.boxplot((train["imp_cons"].dropna()), ax=axs[5])

axs[0].ticklabel_format(style='plain', axis='x')
axs[1].ticklabel_format(style='plain', axis='x')
axs[2].ticklabel_format(style='plain', axis='x')
axs[3].ticklabel_format(style='plain', axis='x')
axs[4].ticklabel_format(style='plain', axis='x')
axs[5].ticklabel_format(style='plain', axis='x')

plt.show()

# %% [markdown]
# ### Checking for negative values

# %%
train.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.609600e+04  1.609600e+04     1.609600e+04       16096.000000
# mean   1.948044e+05  3.191164e+04     1.946154e+04        2370.555949
# std    6.795151e+05  1.775885e+05     8.235676e+04        4035.085664
# min   -1.252760e+05 -3.037000e+03    -9.138600e+04      -16689.260000
# 25%    5.906250e+03  0.000000e+00     0.000000e+00         513.230000
# 50%    1.533250e+04  0.000000e+00     9.010000e+02        1179.160000
# 75%    5.022150e+04  0.000000e+00     4.127000e+03        2692.077500
# max    1.609711e+07  4.188440e+06     4.538720e+06      103801.930000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        16096.000000              15970.000000             16096.000000
# mean          1907.347229                  0.991547                70.309945
# std           5257.364759                  5.160969                79.023251
# ...

# %%
history.describe()
# Out:
#         price_p1_var   price_p2_var   price_p3_var   price_p1_fix  \
# count  193002.000000  193002.000000  193002.000000  193002.000000
# mean        0.141027       0.054630       0.030496      43.332175
# std         0.025032       0.049924       0.036298       5.419345
# min         0.000000       0.000000       0.000000      -0.177779
# 25%         0.125976       0.000000       0.000000      40.728885
# 50%         0.146033       0.085483       0.000000      44.266930
# 75%         0.151635       0.101673       0.072558      44.444710
# max         0.280700       0.229788       0.114102      59.444710
#
#         price_p2_fix   price_p3_fix
# count  193002.000000  193002.000000
# mean       10.622871       6.409981
# std        12.841899       7.773595
# min        -0.097752      -0.065172
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%        24.339581      16.226389
# max        36.490692      17.458221

# %% [markdown]
# We can see that there are negative values for price_p1_fix , price_p2_fix and price_p3_fix .
#
# Further exploring on those we can see there are only about 10 entries which are negative. This is more likely to be due to corrupted data .
#
# We will replace the negative values with the median (most frequent value)

# %%
history[(history['price_p1_fix'] < 0) | (history['price_p2_fix'] < 0) | (history['price_p3_fix'] < 0)]
# Out:
#                                       id price_date  price_p1_var  \
# 23138   951d99fe07ca94c2139f43bc37095139 2015-03-01      0.125976
# 28350   f7bdc6fa1067cd26fd80bfb9f3fca28f 2015-03-01      0.131032
# 98575   9b523ad5ba8aa2e524dcda5b3d54dab2 2015-02-01      0.129444
# 113467  cfd098ee6c567eb32374c77d20571bc7 2015-02-01      0.123086
# 118467  51d7d8a0bf6b8bd94f8c1de7942c66ea 2015-07-01      0.128132
# 125819  decc0a647016e183ded972595cd2b9fb 2015-03-01      0.124937
# 128761  cc214d7c05de3ee17a7691e274ac488e 2015-06-01      0.124675
# 141011  2a4ed325054472e03cdcc9a34693be4b 2015-02-01      0.167317
# 160827  395a6f41bbd1a0f23a64f00645264e78 2015-04-01      0.121352
# 181811  d4a84ff4ec620151ef05bdef0cf27eab 2015-05-01      0.125976
#
#         price_p2_var  price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 23138       0.103395      0.071536     -0.162916     -0.097749     -0.065166
# 28350       0.108896      0.076955     -0.162916     -0.097749     -0.065166
# ...

# %%
history.loc[history["price_p1_fix"] < 0,"price_p1_fix"] = history["price_p1_fix"].median()
history.loc[history["price_p2_fix"] < 0,"price_p2_fix"] = history["price_p2_fix"].median()
history.loc[history["price_p3_fix"] < 0,"price_p3_fix"] = history["price_p3_fix"].median()

# %%
pd.DataFrame({'Columns ' : train.dtypes , "Nulls" : train.isnull().sum()})
# Out:
#                                 Columns   Nulls
# id                                object      0
# activity_new                      object   9545
# channel_sales                     object   4218
# cons_12m                           int64      0
# cons_gas_12m                       int64      0
# cons_last_month                    int64      0
# date_activ                datetime64[ns]      0
# date_end                  datetime64[ns]      0
# date_modif_prod           datetime64[ns]      0
# date_renewal              datetime64[ns]      0
# forecast_cons_12m                float64      0
# forecast_cons_year                 int64      0
# forecast_discount_energy         float64    126
# forecast_meter_rent_12m          float64      0
# forecast_price_energy_p1         float64    126
# forecast_price_energy_p2         float64    126
# forecast_price_pow_p1            float64    126
# has_gas                           object      0
# imp_cons                         float64      0
# ...

# %% [markdown]
# Replacing all other missing values we have in train data with column mean using .mean()

# %%
train.drop(columns = 'activity_new' , inplace = True)
train.loc[train['forecast_discount_energy'].isnull() , 'forecast_discount_energy'] = train['forecast_discount_energy'].mean()
train.loc[train['forecast_price_energy_p1'].isnull() , 'forecast_price_energy_p1'] = train['forecast_price_energy_p1'].mean()
train.loc[train['forecast_price_energy_p2'].isnull() , 'forecast_price_energy_p2'] = train['forecast_price_energy_p2'].mean()
train.loc[train['forecast_price_pow_p1'].isnull() , 'forecast_price_pow_p1'] = train['forecast_price_pow_p1'].mean()
train.loc[train['margin_gross_pow_ele'].isnull() , 'margin_gross_pow_ele'] = train['margin_gross_pow_ele'].mean()
train.loc[train['margin_net_pow_ele'].isnull() , 'margin_net_pow_ele'] = train['margin_net_pow_ele'].mean()
train.loc[train['net_margin'].isnull() , 'net_margin'] = train['net_margin'].mean()
train.loc[train['origin_up'].isnull() , 'origin_up'] = train['origin_up'].value_counts().index[0]
train.loc[train['pow_max'].isnull() , 'pow_max'] = train['pow_max'].mean()

# %%
null_per = (train.isnull().sum()/len(train.index))*100
null_per.plot(kind = 'bar' , figsize = (18,7))
plt.xlabel('Columns')
plt.ylabel('Null Percentage (%)')
plt.show()

# %%
train.loc[train['channel_sales'].isnull() , 'channel_sales'] = train['channel_sales'].value_counts().index[0]
null_per = (train.isnull().sum()/len(train.index))*100
null_per.plot(kind = 'bar' , figsize = (18,7))
plt.xlabel('Columns')
plt.ylabel('Null Percentage (%)')
plt.show()

# %% [markdown]
# # Pickiling

# %%
import os
if not os.path.exists(os.path.join("..", "processed_data")):
    os.makedirs(os.path.join("..", "processed_data"))

# %%
PICKLE_TRAIN_DIR = os.path.join("..", "processed_data", "train.pkl")
PICKLE_HISTORY_DIR = os.path.join("..", "processed_data", "history.pkl")

# %%
pd.to_pickle(train, PICKLE_TRAIN_DIR)
pd.to_pickle(history, PICKLE_HISTORY_DIR)
